# %%
# !python -m spacy download en_core_web_sm
import spacy
nlp = spacy.load('en_core_web_sm')
# Out:
# Collecting en-core-web-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
with open("owlcreek.txt", "r", encoding="utf-8") as f:
    text = f.read()

doc = nlp(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3494/1454962815.py in <cell line: 0>()
# ----> 1 with open("owlcreek.txt", "r", encoding="utf-8") as f:
#       2     text = f.read()
#       3
#       4 doc = nlp(text)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'owlcreek.txt'

# %%
#3.How many sentences are contained in the file?

sentences = list(doc.sents)
print(len(sentences))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3494/4234342965.py in <cell line: 0>()
#       1 #3.How many sentences are contained in the file?
#       2
# ----> 3 sentences = list(doc.sents)
#       4 print(len(sentences))
#
# NameError: name 'doc' is not defined

# %%
#Print the second sentence in the document
print(sentences[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3494/3200440376.py in <cell line: 0>()
#       1 #Print the second sentence in the document
# ----> 2 print(sentences[1])
#
# NameError: name 'sentences' is not defined

# %%
#Write a matcher called 'Swimming' that finds both occurrences of the phrase "swimming vigorously" in the text.
from spacy.matcher import Matcher
doc = nlp(text)
matcher = Matcher(nlp.vocab)
pattern = [
    {"TEXT": "swim"},
    {"TEXT": "vigorously"}
]
matcher.add("Swimming", [pattern])
matches = matcher(doc)

print("Number of matches:", len(matches))
for match_id, start, end in matches:
    print("Match:", doc[start:end].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3494/206075672.py in <cell line: 0>()
#       1 #Write a matcher called 'Swimming' that finds both occurrences of the phrase "swimming vigorously" in the text.
#       2 from spacy.matcher import Matcher
# ----> 3 doc = nlp(text)
#       4 matcher = Matcher(nlp.vocab)
#       5 pattern = [
#
# NameError: name 'text' is not defined

# %%
#Print the text surrounding each found match.
matches = matcher(doc)
for match_id, start, end in matches:
    print(doc[start-5:end+5].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3494/3399821432.py in <cell line: 0>()
#       1 #Print the text surrounding each found match.
# ----> 2 matches = matcher(doc)
#       3 for match_id, start, end in matches:
#       4     print(doc[start-5:end+5].text)
#
# NameError: name 'matcher' is not defined
